# %%
import pandas as pd
import os

# %%
# Diretório dos arquivos Excel
diretorio = r"C:\VilarLearn\Source\Travel"

# Lista para armazenar os DataFrames dos arquivos
dados = []

# Iterar sobre os arquivos Excel no diretório
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.xlsx'):
        caminho_arquivo = os.path.join(diretorio, arquivo)
        dados.append(pd.read_excel(caminho_arquivo))

# Consolidar os dados em um único DataFrame
consolidado = pd.concat(dados, ignore_index=True)

# Exibir o DataFrame consolidado
consolidado
# Out:
#     Número de Voo                Companhia Aérea             Origem  \
# 0            1165                   Black-Castro    Lake Ashleyfurt
# 1            8714     Vega, Robinson and Richard            Ianland
# 2            1042  Anderson, Gonzalez and Kaiser  East Lindsayville
# 3            9423                    Wilkins Inc       North Donald
# 4            9986                    Gray-Vargas        Princemouth
# 5            4720        Mccann, Long and Moreno         Port David
# 6            5665                      Jones Inc     West Catherine
# 7            2584                   Reynolds Ltd        New Richard
# 8            2157                    Cohen-Olson       Davischester
# 9            6684                      Ayers PLC          Donnabury
# 10           3382                 Harrington LLC      Lake Brittany
# 11           1089                   Becker-House        Chapmanfort
# 12           7054                      Miller-Yu        Robertoberg
# 13           9385               Fernandez-Harris          Lake Eric
# 14           4976     Russell, Bryant and Rivera          Ryanburgh
# 15           1165                   Black-Castro    Lake Ashleyfurt
# 16           8714     Vega, Robinson and Richard            Ianland
# 17           1042  Anderson, Gonzalez and Kaiser  East Lindsayville
# 18           9423                    Wilkins Inc       North Donald
# 19           9986                    Gray-Vargas        Princemouth
# 20           4720        Mccann, Long and Moreno         Port David
# 21           5665                      Jones Inc     West Catherine
# 22           2584                   Reynolds Ltd        New Richard
# 23           2157                    Cohen-Olson       Davischester
# 24           6684                      Ayers PLC          Donnabury
# 25           3382                 Harrington LLC      Lake Brittany
# 26           1089                   Becker-House        Chapmanfort
# 27           7054                      Miller-Yu        Robertoberg
# 28           9385               Fernandez-Harris          Lake Eric
# 29           4976     Russell, Bryant and Rivera          Ryanburgh
#
#              Destino Data Partida Data Chegada   Preço  Número de Passageiros  \
# 0       Rodriguezton   2024-11-03   2024-08-26  556.22                      2
# 1    Port Cathyville   2024-06-04   2024-11-07  550.95                      1
# 2          Davidview   2024-12-17   2024-10-04  607.00                      3
# 3       Port Douglas   2024-09-16   2024-09-06  580.23                      2
# 4           Sotobury   2024-04-19   2024-12-23  900.34                      1
# 5            Annview   2024-01-03   2024-06-08  602.35                      3
# 6         Robertbury   2024-08-25   2024-05-08  705.07                      4
# 7         Janetshire   2024-03-27   2024-10-04  689.14                      3
# 8   Port Zacharyside   2024-12-15   2024-04-04  951.13                      5
# 9         Amychester   2024-11-01   2024-12-21  131.55                      3
# 10  East Sheilamouth   2024-01-04   2024-04-29  796.80                      5
# 11          Mooreton   2024-03-29   2024-08-18  556.49                      2
# 12       Lake Travis   2024-02-03   2024-07-28  267.06                      1
# 13      Brianchester   2024-08-28   2024-03-31  807.12                      3
# 14        North Gary   2024-07-29   2024-05-07  444.55                      1
# 15      Rodriguezton   2024-11-03   2024-08-26  556.22                      2
# 16   Port Cathyville   2024-06-04   2024-11-07  550.95                      1
# 17         Davidview   2024-12-17   2024-10-04  607.00                      3
# 18      Port Douglas   2024-09-16   2024-09-06  580.23                      2
# 19          Sotobury   2024-04-19   2024-12-23  900.34                      1
# 20           Annview   2024-01-03   2024-06-08  602.35                      3
# 21        Robertbury   2024-08-25   2024-05-08  705.07                      4
# 22        Janetshire   2024-03-27   2024-10-04  689.14                      3
# 23  Port Zacharyside   2024-12-15   2024-04-04  951.13                      5
# 24        Amychester   2024-11-01   2024-12-21  131.55                      3
# 25  East Sheilamouth   2024-01-04   2024-04-29  796.80                      5
# 26          Mooreton   2024-03-29   2024-08-18  556.49                      2
# 27       Lake Travis   2024-02-03   2024-07-28  267.06                      1
# 28      Brianchester   2024-08-28   2024-03-31  807.12                      3
# 29        North Gary   2024-07-29   2024-05-07  444.55                      1
#
#              Classe
# 0         Executiva
# 1         Executiva
# 2         Executiva
# 3         Executiva
# 4   Primeira Classe
# 5         Econômica
# 6   Primeira Classe
# 7   Primeira Classe
# 8         Econômica
# 9         Executiva
# 10        Econômica
# 11        Econômica
# 12        Executiva
# 13        Executiva
# 14        Executiva
# 15        Executiva
# 16        Executiva
# 17        Executiva
# 18        Executiva
# 19  Primeira Classe
# 20        Econômica
# 21  Primeira Classe
# 22  Primeira Classe
# 23        Econômica
# 24        Executiva
# 25        Econômica
# 26        Econômica
# 27        Executiva
# 28        Executiva
# 29        Executiva

# %%
from sqlalchemy import create_engine

# Configurações da conexão com o Azure SQL
server = 'seu_server.database.windows.net'
database = 'seu_banco_de_dados'
username = 'Seu_usuario'
password = 'Sua_senha'
driver = 'ODBC Driver 17 for SQL Server'

# Construir a string de conexão
conn_str = f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver={driver}"

# Criar uma conexão com o banco de dados
engine = create_engine(conn_str)

# Nome da tabela no Azure SQL
nome_tabela = 'Viagens'

# Enviar DataFrame para o Azure SQL
consolidado.to_sql(nome_tabela, con=engine, if_exists='replace', index=False)

# Fechar a conexão
engine.dispose()
