# %% [markdown]
# Importando Pandas e NumPy

# %% [markdown]
# O Numpy é uma biblioteca que nos permite trabalhar com funções matemáticas mais complexas com a linguagem python. Pandas é a ferramenta principal para construção de estrutura, manipulação e limpeza de dados na linguagem python

# %%
#importando as bibliotecas do pandas e numpy
import pandas as pd
import numpy as np

# %%
url = ('https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/tips.csv')

# %%
#criação do dataframe no pandas
tb = pd.read_csv(url)

# %%
#verifica o tamanho do dataframe
len(tb)
# Out:
# 244

# %% [markdown]
# **Importar arquivos**

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cad1f1c5-cf06-4e88-b39c-ee745b34c937" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cad1f1c5-cf06-4e88-b39c-ee745b34c937">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd 
import io 
  
df = pd.read_xlxs(io.BytesIO(uploaded['Inad_amostra.csv'])) 
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-776a2912ae4e> in <module>
#       2 import io
#       3
# ----> 4 df = pd.read_csv(io.BytesIO(uploaded['Inad_amostra.csv']))
#       5 print(df)
#
# KeyError: 'Inad_amostra.csv'

# %% [markdown]
# **Consulta os dados**

# %%
#vendo as primeiras linhas
tb.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#retorna as 3 primeiras linhas com determinadas colunas
tb[['total_bill','tip','smoker','time']].head(3)
# Out:
#    total_bill   tip smoker    time
# 0       16.99  1.01     No  Dinner
# 1       10.34  1.66     No  Dinner
# 2       21.01  3.50     No  Dinner

# %%
#consulta tabela onde a coluna "timer" conter o registro "Dinner"
tb[tb['time']=='Dinner'].head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#consulta na tabela onde a coluna "time" conter o registro "Dinner" e a coluna "tip" com valores maior e igual a 5
tb[(tb['time']=='Dinner') & (tb['tip'] >= 5.00)]
# Out:
#      total_bill    tip sexo smoker  dia    time  size data_atualizacao
# 11        35.26   5.00  NaN     No  Sun  Dinner     4       2022-12-02
# 23        39.42   7.58  NaN     No  Sat  Dinner     4       2022-12-02
# 39        31.27   5.00  NaN     No  Sat  Dinner     3       2022-12-02
# 44        30.40   5.60  NaN     No  Sun  Dinner     4       2022-12-02
# 46        22.23   5.00  NaN     No  Sun  Dinner     2       2022-12-02
# 47        32.40   6.00  NaN     No  Sun  Dinner     4       2022-12-02
# 52        34.81   5.20  NaN     No  Sun  Dinner     4       2022-12-02
# 59        48.27   6.73  NaN     No  Sat  Dinner     4       2022-12-02
# 73        25.28   5.00  NaN    Yes  Sat  Dinner     2       2022-12-02
# 116       29.93   5.07  NaN     No  Sun  Dinner     4       2022-12-02
# 155       29.85   5.14  NaN     No  Sun  Dinner     5       2022-12-02
# 156       48.17   5.00  NaN     No  Sun  Dinner     6       2022-12-02
# ...

# %%
##Filtra os registros da tabela onde tem "Dinner" como se fosse a cláusula where no SQL
tb[tb.time =='Dinner']
# Out:
#      total_bill   tip     sex smoker   day    time  size    Nova Coluna  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Não Informado
# 1         10.34  1.66    Male     No   Sun  Dinner     3  Não Informado
# 2         21.01  3.50    Male     No   Sun  Dinner     3  Não Informado
# 3         23.68  3.31    Male     No   Sun  Dinner     2  Não Informado
# 4         24.59  3.61  Female     No   Sun  Dinner     4  Não Informado
# ..          ...   ...     ...    ...   ...     ...   ...            ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  Não Informado
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  Não Informado
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  Não Informado
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Não Informado
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Não Informado
#
#     data_atualizacao
# 0         2022-12-03
# 1         2022-12-03
# 2         2022-12-03
# ...

# %%
#conta os valores únicos em uma coluna
df2 = tb.day.nunique()
df2
# Out:
# 4

# %%
#conta a quantidade de registros para determinado campo
df = tb.day.value_counts()
df
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
# usando a função capitalize para retornar a primeira letra em maiúscula. o UPPER() retornaria o nome inteio em maiúscula
name = "joao vilar"
name.capitalize()
# Out:
# 'Joao vilar'

# %% [markdown]
# **Consulta campos nulos**

# %%
#retorna true se tiver campo com valor nulo
pd.isnull(tb)
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
#Mesmo retorn de cima, verifica se tem alguma coluna com valor nulo em toda a tabela. True representa que tem, false representa que não tem
tb.isna()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
#Filtra a tabela onde a coluna possui valor nulo
tb[tb['tip'].isna()]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
#valores não nulos na coluna "tip"
tb[tb['tip'].notna()]
# Out:
#      total_bill   tip     sex smoker   day    time  size    Nova Coluna  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Não Informado
# 1         10.34  1.66    Male     No   Sun  Dinner     3  Não Informado
# 2         21.01  3.50    Male     No   Sun  Dinner     3  Não Informado
# 3         23.68  3.31    Male     No   Sun  Dinner     2  Não Informado
# 4         24.59  3.61  Female     No   Sun  Dinner     4  Não Informado
# ..          ...   ...     ...    ...   ...     ...   ...            ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  Não Informado
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  Não Informado
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  Não Informado
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Não Informado
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Não Informado
#
#     data_atualizacao
# 0         2022-12-03
# 1         2022-12-03
# 2         2022-12-03
# ...

# %% [markdown]
# **Group by**

# %%
#Groupby - nesse campo está contando a quantidade e o campo e necessariamente é preciso agrupar
tb.groupby('sex').size()
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
#mesmo resultado acima usando o size(), só que agora usando o count
tb.groupby('sex')['total_bill'].count()
# Out:
# sex
# Female     87
# Male      157
# Name: total_bill, dtype: int64

# %%
# Somando o campo "total_bill" agrupando por sexo
tb.groupby('sex')['total_bill'].sum()
# Out:
# sex
# Female    1570.95
# Male      3256.82
# Name: total_bill, dtype: float64

# %%
#conta a quantidade de registros da coluna time, agrupando sex e day
tab = tb.groupby(['sex', 'day'])['time'].nunique()

pd.DataFrame(tab).reset_index()
# Out:
#       sex   day  time
# 0  Female   Fri     2
# 1  Female   Sat     1
# 2  Female   Sun     1
# 3  Female  Thur     2
# 4    Male   Fri     2
# 5    Male   Sat     1
# 6    Male   Sun     1
# 7    Male  Thur     1

# %% [markdown]
# **Adicionando nova coluna na tabela**

# %%
#Criando nova coluna 
tb['Nova Coluna'] = 'Não Informado'
tb.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size data_atualizacao  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2       2022-12-03
# 1       10.34  1.66    Male     No  Sun  Dinner     3       2022-12-03
# 2       21.01  3.50    Male     No  Sun  Dinner     3       2022-12-03
# 3       23.68  3.31    Male     No  Sun  Dinner     2       2022-12-03
# 4       24.59  3.61  Female     No  Sun  Dinner     4       2022-12-03
#
#      Nova Coluna
# 0  Não Informado
# 1  Não Informado
# 2  Não Informado
# 3  Não Informado
# 4  Não Informado

# %%
#retorna a data do dia corrente
from datetime import date

data_atual = date.today()
print(data_atual)
# Out:
# 2022-12-03

# %%
#adiciona coluna da data atual no dataframe
tb['data_atualizacao'] = data_atual
tb
# Out:
#      total_bill   tip     sex smoker   day    time  size data_atualizacao
# 0         16.99  1.01  Female     No   Sun  Dinner     2       2022-12-03
# 1         10.34  1.66    Male     No   Sun  Dinner     3       2022-12-03
# 2         21.01  3.50    Male     No   Sun  Dinner     3       2022-12-03
# 3         23.68  3.31    Male     No   Sun  Dinner     2       2022-12-03
# 4         24.59  3.61  Female     No   Sun  Dinner     4       2022-12-03
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       2022-12-03
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       2022-12-03
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       2022-12-03
# 242       17.82  1.75    Male     No   Sat  Dinner     2       2022-12-03
# 243       18.78  3.00  Female     No  Thur  Dinner     2       2022-12-03
#
# [244 rows x 8 columns]

# %%
#formata a data em string - DDMMYYYY
data_em_texto = data_atual.strftime('%d/%m/%Y')
data_em_texto
# Out:
# '02/12/2022'

# %%
from datetime import datetime

data_e_hora_atuais = datetime.now()
data_e_hora_em_texto = data_e_hora_atuais.strftime('%d/%m/%Y')

print(data_e_hora_em_texto)
# Out:
# 03/12/2022

# %%
#resolve problema de fuso horário no horário da data e hora
from pandas.core.arrays.datetimelike import timedelta
from datetime import datetime, timezone

diferenca = timedelta(hours=-3)
print(diferenca)

fuso_horario = timezone(diferenca)
print(fuso_horario)

data_e_hora_bsb = data_e_hora_atuais.astimezone(fuso_horario)
data_e_hora_bsb_em_texto = data_e_hora_bsb.strftime('%d/%m/%Y %H:%M')

print(data_e_hora_bsb_em_texto)
# Out:
# -1 day, 21:00:00
# UTC-03:00
# 03/12/2022 12:48

# %%
#Cria coluna com condicional
tb['Dia_Semana'] = tb.day.apply(lambda x: 'Sábado' if 'Sat' in x 
                                       else ('Domingo' if 'Sun' in x 
                                             else ('Quinta-feira' if 'Thur' in x
                                              else ('Sexta-feira' if 'Friday' in x 
                                                   else 'NI'))))
tb.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size data_atualizacao  \
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2       2022-12-03
# 235       10.07  1.25    Male     No   Sat  Dinner     2       2022-12-03
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2       2022-12-03
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2       2022-12-03
# 238       35.83  4.67  Female     No   Sat  Dinner     3       2022-12-03
# 239       29.03  5.92    Male     No   Sat  Dinner     3       2022-12-03
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       2022-12-03
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       2022-12-03
# 242       17.82  1.75    Male     No   Sat  Dinner     2       2022-12-03
# 243       18.78  3.00  Female     No  Thur  Dinner     2       2022-12-03
#
#        Nova Coluna    Dia_Semana
# 234  Não Informado        Sábado
# 235  Não Informado        Sábado
# 236  Não Informado        Sábado
# ...

# %% [markdown]
# **Exclusão de coluna**

# %%
#excluindo coluna
tb.drop(['Nova Coluna'], axis=1, inplace=True)
tb
# Out:
#      total_bill   tip     sex smoker   day    time  size data_atualizacao  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2       2022-12-03
# 1         10.34  1.66    Male     No   Sun  Dinner     3       2022-12-03
# 2         21.01  3.50    Male     No   Sun  Dinner     3       2022-12-03
# 3         23.68  3.31    Male     No   Sun  Dinner     2       2022-12-03
# 4         24.59  3.61  Female     No   Sun  Dinner     4       2022-12-03
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       2022-12-03
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       2022-12-03
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       2022-12-03
# 242       17.82  1.75    Male     No   Sat  Dinner     2       2022-12-03
# 243       18.78  3.00  Female     No  Thur  Dinner     2       2022-12-03
#
#        Dia_Semana
# 0         Domingo
# 1         Domingo
# 2         Domingo
# ...

# %%
#excluir colunas
tb.drop(columns=['data_atualizacao','Dia_Semana'], 
                inplace=True)
tb
# Out:
#      total_bill   tip     sex smoker   day    time  size    Nova Coluna
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Não Informado
# 1         10.34  1.66    Male     No   Sun  Dinner     3  Não Informado
# 2         21.01  3.50    Male     No   Sun  Dinner     3  Não Informado
# 3         23.68  3.31    Male     No   Sun  Dinner     2  Não Informado
# 4         24.59  3.61  Female     No   Sun  Dinner     4  Não Informado
# ..          ...   ...     ...    ...   ...     ...   ...            ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  Não Informado
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  Não Informado
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  Não Informado
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Não Informado
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Não Informado
#
# [244 rows x 8 columns]

# %% [markdown]
# **Renomear coluna e campo**

# %%
#renomeia o nome da coluna
tb.rename(columns={'day':'dia',
                   'sex':'sexo'},
          inplace=True)
tb
# Out:
#      total_bill   tip    sexo smoker   dia    time  size data_atualizacao  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2       2022-12-03
# 1         10.34  1.66    Male     No   Sun  Dinner     3       2022-12-03
# 2         21.01  3.50    Male     No   Sun  Dinner     3       2022-12-03
# 3         23.68  3.31    Male     No   Sun  Dinner     2       2022-12-03
# 4         24.59  3.61  Female     No   Sun  Dinner     4       2022-12-03
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       2022-12-03
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       2022-12-03
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       2022-12-03
# 242       17.82  1.75    Male     No   Sat  Dinner     2       2022-12-03
# 243       18.78  3.00  Female     No  Thur  Dinner     2       2022-12-03
#
#        Dia_Semana
# 0         Domingo
# 1         Domingo
# 2         Domingo
# ...

# %%
#renomeia o nome do registro da coluna

tb['sexo'] = tb['sexo'].map({'Male':'Masculino',
                             'Female':'Feminimo'},
                             na_action=None)

tb
# Out:
#      total_bill   tip       sexo smoker   dia    time  size data_atualizacao  \
# 0         16.99  1.01   Feminimo     No   Sun  Dinner     2       2022-12-03
# 1         10.34  1.66  Masculino     No   Sun  Dinner     3       2022-12-03
# 2         21.01  3.50  Masculino     No   Sun  Dinner     3       2022-12-03
# 3         23.68  3.31  Masculino     No   Sun  Dinner     2       2022-12-03
# 4         24.59  3.61   Feminimo     No   Sun  Dinner     4       2022-12-03
# ..          ...   ...        ...    ...   ...     ...   ...              ...
# 239       29.03  5.92  Masculino     No   Sat  Dinner     3       2022-12-03
# 240       27.18  2.00   Feminimo    Yes   Sat  Dinner     2       2022-12-03
# 241       22.67  2.00  Masculino    Yes   Sat  Dinner     2       2022-12-03
# 242       17.82  1.75  Masculino     No   Sat  Dinner     2       2022-12-03
# 243       18.78  3.00   Feminimo     No  Thur  Dinner     2       2022-12-03
#
#        Dia_Semana
# 0         Domingo
# ...

# %% [markdown]
# **Filtrando linhas**

# %%
#filtrando linhas em uma tabela/dataframe
filtro  = tb['size'] > 2
df_filtro = tb[filtro]

df_filtro.tail(10)
# Out:
#      total_bill   tip sexo smoker  dia    time  size data_atualizacao
# 212       48.33  9.00  NaN     No  Sat  Dinner     4       2022-12-02
# 214       28.17  6.50  NaN    Yes  Sat  Dinner     3       2022-12-02
# 216       28.15  3.00  NaN    Yes  Sat  Dinner     5       2022-12-02
# 219       30.14  3.09  NaN    Yes  Sat  Dinner     4       2022-12-02
# 223       15.98  3.00  NaN     No  Fri   Lunch     3       2022-12-02
# 227       20.45  3.00  NaN     No  Sat  Dinner     4       2022-12-02
# 230       24.01  2.00  NaN    Yes  Sat  Dinner     4       2022-12-02
# 231       15.69  3.00  NaN    Yes  Sat  Dinner     3       2022-12-02
# 238       35.83  4.67  NaN     No  Sat  Dinner     3       2022-12-02
# 239       29.03  5.92  NaN     No  Sat  Dinner     3       2022-12-02

# %% [markdown]
# **Verifica o tipo de dados**

# %%
#Mostra os tipos de dados de uma tabela
tb.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
#fornece algumas informações sobre a tabela/dataframe como números de colunas, de linhas e a memória que se está utilizando.
tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, Não Informado to Não Informado
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 23.4+ KB

# %% [markdown]
# **Utilizando INNER JOIN**

# %%
#inner join
import pandas as pd
  
# Criando um dataframe A
a = pd.DataFrame()
  
# Criando um dicionário com os dados para tabela A
dados = {'id': [1, 2, 10, 12,15],
     'val1': ['a', 'b', 'c', 'd','e']}
  
a = pd.DataFrame(dados)

#############################################################
  
# Criando um dataframe B
b = pd.DataFrame()
  
# Criando um dicionário com os dados para tabela B
dados = {'id': [1, 2, 9, 8,15],
     'val1': ['p', 'q', 'r', 's','x']}
b = pd.DataFrame(dados)
  
# inner join
df = pd.merge(a, b, on='id', how='inner')
  
# display dataframe
df
# Out:
#    id val1_x val1_y
# 0   1      a      p
# 1   2      b      q
# 2  15      e      x
